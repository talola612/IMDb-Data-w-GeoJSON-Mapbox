# %%
import requests
import re
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
import time

# %%
#https://mubi.com/lists/the-top-1000

# %%
def load_more():
    driver = webdriver.Chrome()
    url = 'https://mubi.com/lists/the-top-1000'
    driver.get(url)
    time.sleep(2)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    button = driver.find_element_by_css_selector('#multi-films > div > div > button')
    button.click()
    time.sleep(2)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    button = driver.find_element_by_css_selector('#multi-films > div > div > button')
    button.click()
    time.sleep(2)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    button = driver.find_element_by_css_selector('#multi-films > div > div > button')
    button.click()
    time.sleep(2)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    button = driver.find_element_by_css_selector('#multi-films > div > div > button')
    button.click()
    time.sleep(2)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    button = driver.find_element_by_css_selector('#multi-films > div > div > button')
    button.click()
    time.sleep(2)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    button = driver.find_element_by_css_selector('#multi-films > div > div > button')
    button.click()
    time.sleep(2)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    button = driver.find_element_by_css_selector('#multi-films > div > div > button')
    button.click()
    time.sleep(2)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    button = driver.find_element_by_css_selector('#multi-films > div > div > button')
    button.click()
    time.sleep(2)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    button = driver.find_element_by_css_selector('#multi-films > div > div > button')
    button.click()
    time.sleep(2)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    button = driver.find_element_by_css_selector('#multi-films > div > div > button')
    button.click()
    time.sleep(2)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    button = driver.find_element_by_css_selector('#multi-films > div > div > button')
    button.click()
    time.sleep(2)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    button = driver.find_element_by_css_selector('#multi-films > div > div > button')
    button.click()
    time.sleep(2)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    button = driver.find_element_by_css_selector('#multi-films > div > div > button')
    button.click()
    time.sleep(2)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    button = driver.find_element_by_css_selector('#multi-films > div > div > button')
    button.click()
    time.sleep(2)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    button = driver.find_element_by_css_selector('#multi-films > div > div > button')
    button.click()
    time.sleep(2)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    button = driver.find_element_by_css_selector('#multi-films > div > div > button')
    button.click()
    time.sleep(2)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    button = driver.find_element_by_css_selector('#multi-films > div > div > button')
    button.click()
    time.sleep(2)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    button = driver.find_element_by_css_selector('#multi-films > div > div > button')
    button.click()
    time.sleep(2)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    button = driver.find_element_by_css_selector('#multi-films > div > div > button')
    button.click()
    time.sleep(2)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    button = driver.find_element_by_css_selector('#multi-films > div > div > button')
    button.click()
    time.sleep(2)
    movies = driver.find_element_by_class_name('film-grid').find_elements_by_tag_name('li')
    rows = []
    for movie in movies:
        info = movie.find_elements_by_class_name('list-film-text')
        row = {}
        row['img'] = movie.find_element_by_class_name('film-thumb').get_attribute('src')
        for i in info:
            row['rank'] = i.find_element_by_class_name('list-film-position').text
            row['title'] = i.find_element_by_tag_name('h3').text
            row['director'] = i.find_element_by_tag_name('a').text
            row['year'] = re.findall(r'.+(\d\d\d\d)', i.find_element_by_class_name('film-meta-core').find_element_by_class_name('director-year').text.strip())[0]
            row['url'] = i.find_element_by_tag_name('a').get_attribute('href')
        rows.append(row)
    df = pd.DataFrame(rows)
    return(df)

# %%
mubi = load_more()

# %%
mubi = mubi[['title', 'rank', 'director', 'year', 'url', 'img']]
mubi
# Out:
#                                                  title  rank  \
# 0                                        THE GODFATHER     1
# 1                                        SEVEN SAMURAI     2
# 2                                2001: A SPACE ODYSSEY     3
# 3                               THE GODFATHER: PART II     4
# 4                                              STALKER     5
# 5    DR. STRANGELOVE OR: HOW I LEARNED TO STOP WORR...     6
# 6                                       APOCALYPSE NOW     7
# 7                                         CITIZEN KANE     8
# 8                                                   8½     9
# 9                                              PERSONA    10
# 10                                        PULP FICTION    11
# 11                                         TAXI DRIVER    12
# 12                                       SPIRITED AWAY    13
# 13                                         REAR WINDOW    14
# ...

# %%
mubi.to_csv('mubi_top1000.csv', index = False)
